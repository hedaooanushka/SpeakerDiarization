# %%
import torch

# %%
state_dict = torch.load("videoWeights/unified_model_epoch_4.pth", map_location=torch.device('cpu'))

# %%
state_dict.keys()
# Out:
# odict_keys(['backbone.conv1.weight', 'backbone.bn1.weight', 'backbone.bn1.bias', 'backbone.bn1.running_mean', 'backbone.bn1.running_var', 'backbone.bn1.num_batches_tracked', 'backbone.resnet_conv_block1.conv1.weight', 'backbone.resnet_conv_block1.bn1.weight', 'backbone.resnet_conv_block1.bn1.bias', 'backbone.resnet_conv_block1.bn1.running_mean', 'backbone.resnet_conv_block1.bn1.running_var', 'backbone.resnet_conv_block1.bn1.num_batches_tracked', 'backbone.resnet_conv_block1.conv2.weight', 'backbone.resnet_conv_block1.bn2.weight', 'backbone.resnet_conv_block1.bn2.bias', 'backbone.resnet_conv_block1.bn2.running_mean', 'backbone.resnet_conv_block1.bn2.running_var', 'backbone.resnet_conv_block1.bn2.num_batches_tracked', 'backbone.resnet_conv_block1.conv3.weight', 'backbone.resnet_conv_block1.bn3.weight', 'backbone.resnet_conv_block1.bn3.bias', 'backbone.resnet_conv_block1.bn3.running_mean', 'backbone.resnet_conv_block1.bn3.running_var', 'backbone.resnet_conv_block1.bn3.num_batches_tracke
# ...
